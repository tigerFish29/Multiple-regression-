# %%
import pandas as pd 
import numpy as np 
import pylab as pl 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Auto.csv")

# %%
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
# select the features you want for regression

# %%
more_features = data[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY','FUELCONSUMPTION_COMB','CO2EMISSIONS']]

# %%
more_features.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
# 5         3.5          6                  11.9                  7.7
# 6         3.5          6                  11.8                  8.1
# 7         3.7          6                  12.8                  9.0
# 8         3.7          6                  13.4                  9.5
#
#    FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0                   8.5           196
# 1                   9.6           221
# 2                   5.9           136
# 3                  11.1           255
# 4                  10.6           244
# 5                  10.0           230
# ...

# %%
# plot the features you like

# %%
plt.figure(figsize=(10,4), dpi=150)
sns.scatterplot(data=more_features, x="ENGINESIZE", y="CO2EMISSIONS")
# Out:
# <AxesSubplot:xlabel='ENGINESIZE', ylabel='CO2EMISSIONS'>

# %%
# creating test and train data sets

# %%
split = np.random.rand(len(data)) < 0.8
train = more_features[split]
test = more_features[~split]

# %%
plt.figure(figsize=(10,4), dpi=150)
sns.scatterplot(data=train, x="ENGINESIZE", y="CO2EMISSIONS")
# Out:
# <AxesSubplot:xlabel='ENGINESIZE', ylabel='CO2EMISSIONS'>

# %%
# Multiple Regression Model

# %%
from sklearn import linear_model
regression = linear_model.LogisticRegression()
x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
y = np.asanyarray(train[['CO2EMISSIONS']])
regression.fit(x,y)
# coefficients 
print("Coefficients: ", regression.coef_)
# Out:
# C:\Users\paulchabz\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Coefficients:  [[-2.59604133e-01  1.46136863e+00 -1.02293149e+00]
#  [ 2.44583877e-01  2.10233145e+00 -1.63491851e+00]
#  [-1.00429093e-02  1.61576074e+00 -1.20428466e+00]
#  [-3.45770141e-02  1.03404479e+00 -7.10257417e-01]
#  [ 8.08704565e-01  7.65962097e-01 -9.08854433e-01]
#  [-4.76819902e-01  9.61704277e-01 -6.03046625e-01]
#  [ 5.98016727e-01  1.06238877e+00 -1.01445844e+00]
#  [-3.29886456e-01  1.22378050e+00 -7.80423348e-01]
#  [-5.77677945e-01  1.23467234e+00 -6.97318991e-01]
#  [-2.09983786e+00  2.86551670e-02  2.08637601e-01]
#  [-1.65963481e+00  1.35879439e+00 -4.24205315e-01]
#  [-8.20176152e-01  5.95334449e-01 -3.06915093e-01]
#  [-2.60124343e+00  1.82916623e+00 -6.07780096e-01]
# ...

# %%
from joblib import dump
dump(data, 'filename.joblib')
# Out:
# ['filename.joblib']
